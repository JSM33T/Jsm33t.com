# %%
import os
import faiss
import pickle
import subprocess
from pathlib import Path
from sentence_transformers import SentenceTransformer

# === CONFIG ===
TARGET_DIR = "./../../Jsm33t.com/"  # Change this
FILE_EXTENSIONS = {".cs"}
EMBEDDING_MODEL_NAME = "all-MiniLM-L6-v2"
OUTPUT_FAISS = "doc_index.faiss"
OUTPUT_METADATA = "metadata.pkl"

# === INIT ===
model = SentenceTransformer(EMBEDDING_MODEL_NAME)
texts = []
metadatas = []

# === HELPERS ===
def is_gitignored(path: Path) -> bool:
    try:
        subprocess.run(["git", "check-ignore", str(path)],
                       stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
        return True
    except subprocess.CalledProcessError:
        return False

# === FILE WALK ===
for root, _, files in os.walk(TARGET_DIR):
    for file in files:
        path = Path(root) / file
        if path.suffix.lower() in FILE_EXTENSIONS and not is_gitignored(path):
            print(f"Indexing: {path}")
            try:
                content = path.read_text(encoding="utf-8", errors="ignore")
                if content.strip():
                    texts.append(content)
                    metadatas.append(str(path))
            except Exception as e:
                print(f"❌ Skipped {path} due to error: {e}")

# === EMBEDDING + SAVE ===
if texts:
    embeddings = model.encode(texts, show_progress_bar=True, convert_to_numpy=True)
    dimension = embeddings.shape[1]
    index = faiss.IndexFlatL2(dimension)
    index.add(embeddings)

    faiss.write_index(index, OUTPUT_FAISS)
    with open(OUTPUT_METADATA, "wb") as f:
        pickle.dump(metadatas, f)

    print(f"\n✅ Indexed {len(texts)} files → Saved to {OUTPUT_FAISS} + {OUTPUT_METADATA}")
else:
    print("⚠️ No .cs files indexed.")
# Out:
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Program.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Controllers\AuthController.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Controllers\BlogController.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Controllers\ChangeLogController.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Controllers\FcBaseController.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Controllers\MediaCacheController.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Controllers\ProfileController.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Controllers\TestController.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Extensions\ServiceCollectionExtension.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Filters\DeductPointsAttribute.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Filters\DeductPointsFilter.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Middlewares\FcRequestMiddleware.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\Middlewares\RequestTimerMiddleware.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Debug\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Debug\net9.0\Jsm33t.Api.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Debug\net9.0\Jsm33t.Api.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Debug\net9.0\Jsm33t.Api.MvcApplicationPartsAssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Release\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Release\net9.0\Jsm33t.Api.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Release\net9.0\Jsm33t.Api.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Release\net9.0\Jsm33t.Api.MvcApplicationPartsAssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Release\net9.0\win-x64\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Release\net9.0\win-x64\Jsm33t.Api.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Api\obj\Release\net9.0\win-x64\Jsm33t.Api.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.
cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\MailService\SendGrid\SendGridMailService.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\MailService\SmtpMail\SmtpConfig.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\MailService\SmtpMail\SmtpMailService.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\obj\Debug\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\obj\Debug\net9.0\Jsm33t.Infra.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\obj\Debug\net9.0\Jsm33t.Infra.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\obj\Release\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\obj\Release\net9.0\Jsm33t.Infra.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\obj\Release\net9.0\Jsm33t.Infra.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\Telegram\ITelegramService.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\Telegram\MockTelegramService.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\Telegram\TelegramService.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\Token\ITokenService.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\Token\MockTokenService.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Infra\Token\TokenService.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\AuthRepository.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\BlogRepository.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\ChangeLogRepository.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\JobHistoryRepository.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\ProfileRepository.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\obj\Debug\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\obj\Debug\net9.0\Jsm33t.Repositories.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\obj\Debug\net9.0\Jsm33t.Repositories.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\obj\Release\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\obj\Release\net9.0\Jsm33t.Repositories.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Repositories\obj\Release\net9.0\Jsm33t.Repositories.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\ConfigModels\FcConfig.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\Helpers\HttpContextHelper.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\Helpers\PasswordHelper.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\Helpers\ResponseHandlers.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\Helpers\Templates.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\obj\Debug\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\obj\Debug\net9.0\Jsm33t.Shared.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\obj\Debug\net9.0\Jsm33t.Shared.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\obj\Release\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\obj\Release\net9.0\Jsm33t.Shared.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Shared\obj\Release\net9.0\Jsm33t.Shared.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\ChangePasswordRequestDtoValidator.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\LoginRequestDtoValidator.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\SignupUserRequestDtoValidator.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\obj\Debug\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\obj\Debug\net9.0\Jsm33t.Validators.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\obj\Debug\net9.0\Jsm33t.Validators.GlobalUsings.g.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\obj\Release\net9.0\.NETCoreApp,Version=v9.0.AssemblyAttributes.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\obj\Release\net9.0\Jsm33t.Validators.AssemblyInfo.cs
# Indexing: ..\..\Jsm33t.com\Jsm33t.Validators\obj\Release\net9.0\Jsm33t.Validators.GlobalUsings.g.cs
# Batches: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# ✅ Indexed 130 files → Saved to doc_index.faiss + metadata.pkl
